# %% [markdown]
# ## Import

# %%
## Import Pandas and Numpy
import pandas as pd
import numpy as np

# %%
## set column limit to 500

pd.set_option("display.max_columns",500)

# %%
## import matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import random
import datetime
import warnings
import os
warnings.filterwarnings('ignore')

# %% [markdown]
# ### rcParams for better visualization!

# %%
# Imports for better visualization
from matplotlib import rcParams
#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 4)
rcParams['figure.dpi'] = 150
#rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['font.size'] = 8
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'

# %% [markdown]
# ### Data Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %%time
train = pd.read_csv('/content/drive/My Drive/Shaastra Workshop Material/EDA_and_Preprocessing/data/train_foreclosure.csv')
test = pd.read_csv('/content/drive/My Drive/Shaastra Workshop Material/EDA_and_Preprocessing/data/test_foreclosure.csv')
customers = pd.read_excel('/content/drive/My Drive/Shaastra Workshop Material/EDA_and_Preprocessing/data/Customers_31JAN2019.xlsx')
query = pd.read_excel('/content/drive/My Drive/Shaastra Workshop Material/EDA_and_Preprocessing/data/RF_Final_Data.xlsx')
# Out:
# CPU times: user 1.51 s, sys: 16.1 ms, total: 1.53 s
# Wall time: 2.56 s

# %%
# %%time
agreements = pd.read_excel('/content/drive/My Drive/Shaastra Workshop Material/EDA_and_Preprocessing/data/LMS_31JAN2019.xlsx')
# Out:
# CPU times: user 3min 12s, sys: 2.41 s, total: 3min 14s
# Wall time: 3min 16s

# %% [markdown]
# ### Raw Data Analysis

# %%
### print first 5 rows of train
train.head()
# Out:
#    AGREEMENTID  FORECLOSURE
# 0     11220001            1
# 1     11220002            1
# 2     11220006            1
# 3     11220008            1
# 4     11220010            1

# %%
### Same for test
test.head()
# Out:
#    AGREEMENTID  FORECLOSURE
# 0     11220003          NaN
# 1     11220004          NaN
# 2     11220005          NaN
# 3     11220007          NaN
# 4     11220009          NaN

# %%
### same for customer file
customers.head()
# Out:
#    CUSTOMERID  CUST_CONSTTYPE_ID  CUST_CATEGORYID  PROFESSION   AGE SEX  \
# 0    12001000                  1                5         NaN  33.0   M
# 1    12001001                  1                5         NaN  44.0   M
# 2    12001002                  1                7         NaN  50.0   M
# 3    12001003                  3                4         NaN  40.0   M
# 4    12001004                  3                4         NaN  27.0   M
#
#   MARITAL_STATUS QUALIFICATION  NO_OF_DEPENDENT  OCCUPATION POSITION  \
# 0              M      POSTGRAD              0.0         NaN      NaN
# 1              M      POSTGRAD              0.0         NaN      NaN
# 2              M          GRAD              0.0         NaN      NaN
# 3              M          GRAD              0.0         NaN      NaN
# 4              M          GRAD              0.0         NaN      NaN
#
#     GROSS_INCOME  PRE_JOBYEARS  NETTAKEHOMEINCOME  BRANCH_PINCODE
# 0  198375.221829           8.0      198375.221829        400070.0
# 1  242703.982915          10.0      242703.982915        400070.0
# 2       0.000000           NaN           0.000000        400070.0
# 3  365263.511624           NaN      365263.516128        400070.0
# 4  187342.198995           NaN      187342.198995        400070.0

# %%
### describe the customer file
customers.describe()
# Out:
#          CUSTOMERID  CUST_CONSTTYPE_ID  CUST_CATEGORYID  PROFESSION  \
# count  1.000000e+04       10000.000000     10000.000000         0.0
# mean   1.200778e+07           1.103600         4.495000         NaN
# std    3.842990e+03           0.526018         0.829605         NaN
# min    1.200100e+07           1.000000         4.000000         NaN
# 25%    1.200464e+07           1.000000         4.000000         NaN
# 50%    1.200787e+07           1.000000         4.000000         NaN
# 75%    1.201094e+07           1.000000         5.000000         NaN
# max    1.203390e+07           6.000000         8.000000         NaN
#
#                AGE  NO_OF_DEPENDENT  OCCUPATION  GROSS_INCOME  PRE_JOBYEARS  \
# count  9604.000000      9921.000000         0.0  1.000000e+04   2375.000000
# mean     40.844648         0.519202         NaN  1.544479e+05      4.554526
# std       9.344151         1.097127         NaN  5.801275e+05      6.254120
# min      18.000000         0.000000         NaN  0.000000e+00      0.000000
# 25%      34.000000         0.000000         NaN  4.503887e+04      0.000000
# 50%      40.000000         0.000000         NaN  7.506479e+04      2.000000
# 75%      48.000000         0.000000         NaN  1.288645e+05      7.000000
# max      76.000000        10.000000         NaN  2.691744e+07     42.000000
#
#        NETTAKEHOMEINCOME  BRANCH_PINCODE
# count       1.000000e+04     9927.000000
# mean        1.536376e+05   469059.826030
# std         5.797531e+05   148742.720744
# min         0.000000e+00        0.000000
# 25%         4.503887e+04   400070.000000
# 50%         7.506479e+04   500034.000000
# 75%         1.285860e+05   602001.000000
# max         2.691744e+07   641601.000000

# %%
agreements.head()
# Out:
#    AGREEMENTID  CUSTOMERID      LOAN_AMT  NET_DISBURSED_AMT  \
# 0     11220001  12001000.0  1.171011e+07       1.171011e+07
# 1     11220002  12001001.0  1.929025e+07       1.929025e+07
# 2     11220003  12001002.0  4.053499e+06       4.053499e+06
# 3     11220004  12001003.0  1.325703e+07       1.325703e+07
# 4     11220005  12001004.0  1.321140e+07       1.321140e+07
#
#   INTEREST_START_DATE  CURRENT_ROI  ORIGNAL_ROI  CURRENT_TENOR  ORIGNAL_TENOR  \
# 0          2010-08-30    13.734072    10.612692           58.0            120
# 1          2010-09-15    13.734072    10.612692          137.0            180
# 2          2010-09-06    17.167590    12.485520          360.0            180
# 3          2010-09-29    15.606900    10.924830          198.0            180
# 4          2010-09-06    16.543314    11.861244          142.0            180
#
#    DUEDAY AUTHORIZATIONDATE    CITY  PRE_EMI_DUEAMT  PRE_EMI_RECEIVED_AMT  \
# 0       1        2010-08-29  MUMBAI     7994.273589           7994.273589
# 1       1        2010-09-15  MUMBAI   100504.575864         100504.575864
# 2       5        2010-09-06  MUMBAI        0.000000              0.000000
# 3       5        2010-09-29  MUMBAI    28441.732656          28441.732656
# 4       5        2010-09-06  MUMBAI        0.000000              0.000000
#
#    PRE_EMI_OS_AMOUNT    EMI_DUEAMT  EMI_RECEIVED_AMT  EMI_OS_AMOUNT  \
# 0                0.0  7.516699e+06      7.332154e+06  184544.396568
# 1                0.0  1.061903e+07      1.033958e+07  279448.084560
# 2                0.0  2.439242e+06      2.439242e+06       0.000000
# 3                0.0  7.211965e+06      7.211965e+06       0.000000
# 4                0.0  7.712034e+06      7.712034e+06       0.000000
#
#    EXCESS_AVAILABLE  EXCESS_ADJUSTED_AMT  BALANCE_EXCESS  NET_RECEIVABLE  \
# 0       29042.45880           29042.4588         0.00000   184544.396568
# 1           0.00000               0.0000         0.00000   279448.084560
# 2           0.44171               0.0000         0.44171       -0.441710
# 3           0.00000               0.0000         0.00000        0.000000
# 4           0.00000               0.0000         0.00000        0.000000
#
#    OUTSTANDING_PRINCIPAL  PAID_PRINCIPAL  PAID_INTEREST  MONTHOPENING  \
# 0           2.262177e+06    9.447930e+06   2.617476e+06  9.338009e+06
# 1           1.234760e+07    6.942656e+06   4.945154e+06  1.713861e+07
# 2           3.944954e+06    1.085444e+05   1.549566e+06  3.944954e+06
# 3           1.030278e+07    2.954253e+06   4.219464e+06  1.255472e+07
# 4           8.479158e+06    4.732245e+06   3.812974e+06  1.178201e+07
#
#   LAST_RECEIPT_DATE  LAST_RECEIPT_AMOUNT  NET_LTV  COMPLETED_TENURE  \
# 0        2013-11-01              83559.0    40.06                39
# 1        2013-11-01             126530.0    84.31                38
# 2        2013-11-05              30898.0    79.34                38
# 3        2013-11-05              88256.0    86.86                37
# 4        2013-11-05              91892.0    40.93                38
#
#    BALANCE_TENURE  DPD    FOIR PRODUCT    SCHEMEID NPA_IN_LAST_MONTH  \
# 0            19.0  0.0  0.6000      HL  10901100.0               NaN
# 1            99.0  0.0  0.6000      HL  10901100.0               NaN
# 2           322.0  0.0  0.9100      HL  10901101.0               NaN
# 3           161.0  0.0  0.9686      HL  10901101.0               NaN
# 4           104.0  0.0  0.7300      HL  10901101.0               NaN
#
#   NPA_IN_CURRENT_MONTH  MOB
# 0                  NaN   39
# 1                  NaN   38
# 2                  NaN   38
# 3                  NaN   38
# 4                  NaN   38

# %%
agreements.describe()
# Out:
#         AGREEMENTID    CUSTOMERID      LOAN_AMT  NET_DISBURSED_AMT  \
# count  6.242500e+05  6.237340e+05  6.242500e+05       6.242500e+05
# mean   1.123081e+07  1.201179e+07  5.828204e+06       5.778192e+06
# std    7.984211e+03  7.961736e+03  1.323121e+07       1.313555e+07
# min    1.122000e+07  1.200100e+07  3.753240e+04       3.753240e+04
# 25%    1.122430e+07  1.200530e+07  1.516309e+06       1.501296e+06
# 50%    1.122894e+07  1.200993e+07  2.627268e+06       2.593211e+06
# 75%    1.123592e+07  1.201690e+07  5.209731e+06       5.166899e+06
# max    1.125335e+07  1.203390e+07  5.704924e+08       5.674589e+08
#
#          CURRENT_ROI    ORIGNAL_ROI  CURRENT_TENOR  ORIGNAL_TENOR  \
# count  624250.000000  624250.000000  624245.000000  624250.000000
# mean       15.068840      14.997058     178.406491     177.910326
# std         2.506164       2.470942      49.490712      44.212338
# min        -5.056636       0.000000       0.000000       0.000000
# 25%        13.109796      13.109796     150.000000     168.000000
# 50%        14.982624      14.982624     180.000000     180.000000
# 75%        17.167590      16.543314     203.000000     180.000000
# max        37.456560      34.147897     713.000000     300.000000
#
#               DUEDAY  PRE_EMI_DUEAMT  PRE_EMI_RECEIVED_AMT  PRE_EMI_OS_AMOUNT  \
# count  624250.000000    6.242500e+05          6.242500e+05       6.242500e+05
# mean        6.405117    6.221159e+04          6.201999e+04       1.915964e+02
# std         3.533971    3.555793e+05          3.549530e+05       9.510358e+03
# min         1.000000    0.000000e+00          0.000000e+00       0.000000e+00
# 25%         5.000000    4.975868e+03          4.967033e+03       0.000000e+00
# 50%         5.000000    1.222875e+04          1.221992e+04       0.000000e+00
# 75%         5.000000    3.607449e+04          3.607449e+04       0.000000e+00
# max        15.000000    3.177540e+07          3.177540e+07       2.089129e+06
#
#          EMI_DUEAMT  EMI_RECEIVED_AMT  EMI_OS_AMOUNT  EXCESS_AVAILABLE  \
# count  6.242500e+05      6.242500e+05   6.242500e+05      6.242500e+05
# mean   1.868918e+06      1.832613e+06   3.630521e+04      2.176622e+05
# std    6.891111e+06      6.782725e+06   5.739616e+05      2.274487e+06
# min    0.000000e+00      0.000000e+00   0.000000e+00      0.000000e+00
# 25%    1.233145e+05      1.215195e+05   0.000000e+00      0.000000e+00
# 50%    4.614637e+05      4.531783e+05   0.000000e+00      1.104276e+00
# 75%    1.403642e+06      1.371928e+06   0.000000e+00      1.329548e+03
# max    3.936390e+08      3.888015e+08   5.899531e+07      2.841642e+08
#
#        EXCESS_ADJUSTED_AMT  BALANCE_EXCESS  NET_RECEIVABLE  \
# count         6.242500e+05    6.242500e+05    6.242500e+05
# mean          2.088516e+05    8.810573e+03    2.768623e+04
# std           2.234830e+06    4.076866e+05    6.818236e+05
# min           0.000000e+00    0.000000e+00   -7.734998e+07
# 25%           0.000000e+00    0.000000e+00   -1.104276e+00
# 50%           0.000000e+00    0.000000e+00    0.000000e+00
# 75%           2.606091e+02    1.104276e+00    0.000000e+00
# max           2.841642e+08    7.734998e+07    5.672502e+07
#
#        OUTSTANDING_PRINCIPAL  PAID_PRINCIPAL  PAID_INTEREST  MONTHOPENING  \
# count           6.242500e+05    6.242500e+05   6.242500e+05  6.242500e+05
# mean            5.303931e+06    5.320235e+05   9.637954e+05  5.442760e+06
# std             1.209923e+07    1.235317e+07   3.293273e+06  1.226295e+07
# min            -7.506479e-01    0.000000e+00   0.000000e+00  0.000000e+00
# 25%             1.441153e+06    1.406301e+04   8.360153e+04  1.469379e+06
# 50%             2.404174e+06    5.964873e+04   2.681067e+05  2.483012e+06
# 75%             4.654986e+06    2.129521e+05   7.640072e+05  4.850362e+06
# max             5.674589e+08    4.885217e+09   1.845529e+08  5.674589e+08
#
#        LAST_RECEIPT_AMOUNT        NET_LTV  COMPLETED_TENURE  BALANCE_TENURE  \
# count         6.122050e+05  624250.000000     624250.000000   624245.000000
# mean          4.855566e+04      48.825046         15.256937      163.149432
# std           2.398423e+05      20.531984         15.549111       52.995329
# min           1.000000e-02       0.380000          0.000000        0.000000
# 25%           1.040000e+04      32.780000          3.000000      128.000000
# 50%           1.900000e+04      50.290000         10.000000      169.000000
# 75%           3.759200e+04      64.840000         23.000000      182.000000
# max           8.496881e+07     104.860000         98.000000      693.000000
#
#                  DPD           FOIR      SCHEMEID            MOB
# count  624219.000000  624250.000000  6.237340e+05  624250.000000
# mean        7.921803      21.479576  1.090119e+07      16.767239
# std        65.112792    2687.131947  8.546587e+01      15.613276
# min         0.000000    -170.330000  1.090110e+07       0.000000
# 25%         0.000000       0.400000  1.090111e+07       5.000000
# 50%         0.000000       0.510000  1.090115e+07      12.000000
# 75%         0.000000       0.690000  1.090129e+07      24.000000
# max      2268.000000  547616.000000  1.090146e+07      98.000000

# %% [markdown]
# ## Datasets

# %%
# check null values in agreements dataframe
"""fill the code here"""

agreements.isna().sum()
# Out:
# AGREEMENTID                   0
# CUSTOMERID                  516
# LOAN_AMT                      0
# NET_DISBURSED_AMT             0
# INTEREST_START_DATE           0
# CURRENT_ROI                   0
# ORIGNAL_ROI                   0
# CURRENT_TENOR                 5
# ORIGNAL_TENOR                 0
# DUEDAY                        0
# AUTHORIZATIONDATE             0
# CITY                          8
# PRE_EMI_DUEAMT                0
# PRE_EMI_RECEIVED_AMT          0
# PRE_EMI_OS_AMOUNT             0
# EMI_DUEAMT                    0
# EMI_RECEIVED_AMT              0
# EMI_OS_AMOUNT                 0
# EXCESS_AVAILABLE              0
# EXCESS_ADJUSTED_AMT           0
# BALANCE_EXCESS                0
# NET_RECEIVABLE                0
# OUTSTANDING_PRINCIPAL         0
# PAID_PRINCIPAL                0
# PAID_INTEREST                 0
# MONTHOPENING                  0
# LAST_RECEIPT_DATE          3787
# LAST_RECEIPT_AMOUNT       12045
# NET_LTV                       0
# COMPLETED_TENURE              0
# BALANCE_TENURE                5
# DPD                          31
# FOIR                          0
# PRODUCT                       0
# SCHEMEID                    516
# NPA_IN_LAST_MONTH        610891
# NPA_IN_CURRENT_MONTH     610814
# MOB                           0
# dtype: int64

# %%
agreements['CUSTOMERID'].dropna().nunique()
# Out:
# 32895

# %%
agreements[agreements['CUSTOMERID'].isna()]
# Out:
#         AGREEMENTID  CUSTOMERID      LOAN_AMT  NET_DISBURSED_AMT  \
# 545787     11252411         NaN  1.411425e+06       1.411425e+06
# 545788     11252412         NaN  2.781796e+06       2.781796e+06
# 570874     11252718         NaN  1.201037e+06       1.201037e+06
# 570875     11252719         NaN  3.727545e+06       3.727545e+06
# 570876     11252411         NaN  1.411425e+06       1.411425e+06
# ...             ...         ...           ...                ...
# 596453     11253329         NaN  4.503887e+06       4.503887e+06
# 596454     11253330         NaN  2.777397e+06       2.221918e+06
# 596455     11253331         NaN  3.116379e+06       3.116379e+06
# 596456     11253332         NaN  2.769891e+06       2.769891e+06
# 596457     11253333         NaN  4.503887e+06       4.503887e+06
#
#        INTEREST_START_DATE  CURRENT_ROI  ORIGNAL_ROI  CURRENT_TENOR  \
# 545787          2018-10-31    17.479728    17.479728          240.0
# 545788          2018-10-31    13.734072    13.734072          180.0
# 570874          2018-11-30    13.734072    13.734072          144.0
# 570875          2018-11-23    13.421934    13.421934          240.0
# 570876          2018-10-31    17.479728    17.479728          240.0
# ...                    ...          ...          ...            ...
# 596453          2018-12-31    13.421934    13.421934          216.0
# 596454          2018-12-31    13.421934    13.421934          240.0
# 596455          2018-12-31    13.109796    13.109796          240.0
# 596456          2018-12-31    13.109796    13.109796          240.0
# 596457          2018-12-31    13.234651    13.234651          144.0
#
#         ORIGNAL_TENOR  DUEDAY AUTHORIZATIONDATE        CITY  PRE_EMI_DUEAMT  \
# 545787            240       5        2018-10-31  AURANGABAD        0.000000
# 545788            180       1        2018-10-31    WARANGAL     1252.248984
# 570874            144       5        2018-11-30       THANE        0.000000
# 570875            240       5        2018-11-23       THANE        0.000000
# 570876            240       5        2018-10-31  AURANGABAD     4039.441608
# ...               ...     ...               ...         ...             ...
# 596453            216       5        2018-12-31   HYDERABAD        0.000000
# 596454            240       5        2018-12-31    AMRAVATI        0.000000
# 596455            240       5        2018-12-31   AHMEDABAD        0.000000
# 596456            240       5        2018-12-31   AHMEDABAD        0.000000
# 596457            144       5        2018-12-31       THANE        0.000000
#
#         PRE_EMI_RECEIVED_AMT  PRE_EMI_OS_AMOUNT  EMI_DUEAMT  EMI_RECEIVED_AMT  \
# 545787              0.000000           0.000000         0.0               0.0
# 545788              0.000000        1252.248984         0.0               0.0
# 570874              0.000000           0.000000         0.0               0.0
# 570875              0.000000           0.000000         0.0               0.0
# 570876           4039.441608           0.000000         0.0               0.0
# ...                      ...                ...         ...               ...
# 596453              0.000000           0.000000         0.0               0.0
# 596454              0.000000           0.000000         0.0               0.0
# 596455              0.000000           0.000000         0.0               0.0
# 596456              0.000000           0.000000         0.0               0.0
# 596457              0.000000           0.000000         0.0               0.0
#
#         EMI_OS_AMOUNT  EXCESS_AVAILABLE  EXCESS_ADJUSTED_AMT  BALANCE_EXCESS  \
# 545787            0.0          0.000000                  0.0        0.000000
# 545788            0.0          0.000000                  0.0        0.000000
# 570874            0.0          0.000000                  0.0        0.000000
# 570875            0.0          0.000000                  0.0        0.000000
# 570876            0.0        260.609136                  0.0      260.609136
# ...               ...               ...                  ...             ...
# 596453            0.0          0.000000                  0.0        0.000000
# 596454            0.0          0.000000                  0.0        0.000000
# 596455            0.0          0.000000                  0.0        0.000000
# 596456            0.0          0.000000                  0.0        0.000000
# 596457            0.0          0.000000                  0.0        0.000000
#
#         NET_RECEIVABLE  OUTSTANDING_PRINCIPAL  PAID_PRINCIPAL  PAID_INTEREST  \
# 545787        0.000000           1.411425e+06             0.0       0.000000
# 545788     1252.248984           2.781796e+06             0.0       0.000000
# 570874        0.000000           1.201037e+06             0.0       0.000000
# 570875        0.000000           3.727545e+06             0.0       0.000000
# 570876     -260.609136           1.411425e+06             0.0    2745.870018
# ...                ...                    ...             ...            ...
# 596453        0.000000           4.503887e+06             0.0       0.000000
# 596454        0.000000           2.221918e+06             0.0       0.000000
# 596455        0.000000           3.116379e+06             0.0       0.000000
# 596456        0.000000           2.769891e+06             0.0       0.000000
# 596457        0.000000           4.503887e+06             0.0       0.000000
#
#         MONTHOPENING LAST_RECEIPT_DATE  LAST_RECEIPT_AMOUNT  NET_LTV  \
# 545787  1.411425e+06        2018-10-31              13867.0    70.95
# 545788  2.781796e+06               NaT                  NaN    59.62
# 570874  1.201037e+06               NaT                  NaN    23.50
# 570875  3.727545e+06        2018-11-23              29300.0    87.23
# 570876  1.411425e+06        2018-11-27                118.0    70.95
# ...              ...               ...                  ...      ...
# 596453  4.503887e+06        2018-12-31              38350.0    39.51
# 596454  2.221918e+06        2018-12-31              21400.0    75.93
# 596455  3.116379e+06        2018-12-31               6124.0    72.36
# 596456  2.769891e+06        2018-12-31              10886.0    89.99
# 596457  4.503887e+06        2018-12-31               9145.0    85.90
#
#         COMPLETED_TENURE  BALANCE_TENURE  DPD  FOIR PRODUCT  SCHEMEID  \
# 545787                 0           240.0  0.0  0.46    STHL       NaN
# 545788                 0           180.0  0.0  0.44   STLAP       NaN
# 570874                 0           144.0  0.0  0.51     LAP       NaN
# 570875                 0           240.0  0.0  0.50    STHL       NaN
# 570876                 0           240.0  0.0  0.46    STHL       NaN
# ...                  ...             ...  ...   ...     ...       ...
# 596453                 0           216.0  0.0  0.55    STHL       NaN
# 596454                 0           240.0  0.0  0.54    STHL       NaN
# 596455                 0           240.0  0.0  0.13      HL       NaN
# 596456                 0           240.0  0.0  0.79      HL       NaN
# 596457                 0           144.0  0.0  0.72      HL       NaN
#
#        NPA_IN_LAST_MONTH NPA_IN_CURRENT_MONTH  MOB
# 545787               NaN                  NaN    0
# 545788               NaN                  NaN    0
# 570874               NaN                  NaN    0
# 570875               NaN                  NaN    0
# 570876               NaN                  NaN    1
# ...                  ...                  ...  ...
# 596453               NaN                  NaN    0
# 596454               NaN                  NaN    0
# 596455               NaN                  NaN    0
# 596456               NaN                  NaN    0
# 596457               NaN                  NaN    0
#
# [516 rows x 38 columns]

# %%
agreements['CUSTOMERID'].nunique()
# Out:
# 32895

# %% [markdown]
# ### MERGE

# %%
print(train.shape)
print(agreements[agreements['AGREEMENTID'].isin(train['AGREEMENTID'].unique())].shape)
# Out:
# (20012, 2)
# (374585, 38)

# %%
train_data = train.merge(agreements,on = 'AGREEMENTID',how= 'left').drop_duplicates()

# %%
train_data.head()
# Out:
#    AGREEMENTID  FORECLOSURE  CUSTOMERID     LOAN_AMT  NET_DISBURSED_AMT  \
# 0     11220001            1  12001000.0  11710107.24        11710107.24
# 1     11220001            1  12001000.0  11710107.24        11710107.24
# 2     11220001            1  12001000.0  11710107.24        11710107.24
# 3     11220001            1  12001000.0  11710107.24        11710107.24
# 4     11220001            1  12001000.0  11710107.24        11710107.24
#
#   INTEREST_START_DATE  CURRENT_ROI  ORIGNAL_ROI  CURRENT_TENOR  ORIGNAL_TENOR  \
# 0          2010-08-30    13.734072    10.612692           58.0            120
# 1          2010-08-30    13.734072    10.612692           58.0            120
# 2          2010-08-30    13.421934    10.612692           58.0            120
# 3          2010-08-30    13.421934    10.612692           58.0            120
# 4          2010-08-30    13.421934    10.612692           58.0            120
#
#    DUEDAY AUTHORIZATIONDATE    CITY  PRE_EMI_DUEAMT  PRE_EMI_RECEIVED_AMT  \
# 0       1        2010-08-29  MUMBAI     7994.273589           7994.273589
# 1       1        2010-08-29  MUMBAI     7994.273589           7994.273589
# 2       1        2010-08-29  MUMBAI     7994.273589           7994.273589
# 3       1        1970-08-30  MUMBAI     7994.273589           7994.273589
# 4       1        2010-08-29  MUMBAI     7994.273589           7994.273589
#
#    PRE_EMI_OS_AMOUNT    EMI_DUEAMT  EMI_RECEIVED_AMT  EMI_OS_AMOUNT  \
# 0                0.0  7.516699e+06      7.332154e+06  184544.396568
# 1                0.0  7.701243e+06      7.516699e+06  184544.396568
# 2                0.0  7.885787e+06      7.701243e+06  184544.396568
# 3                0.0  7.885787e+06      7.885787e+06       0.000000
# 4                0.0  8.254876e+06      8.070332e+06  184544.396568
#
#    EXCESS_AVAILABLE  EXCESS_ADJUSTED_AMT  BALANCE_EXCESS  NET_RECEIVABLE  \
# 0      29042.458800         29042.458800             0.0   184544.396568
# 1      29042.458800         29042.458800             0.0   184544.396568
# 2      29042.458800         29042.458800             0.0   184544.396568
# 3      29042.458800         29042.458800             0.0        0.000000
# 4     213586.855368        213586.855368             0.0   184544.396568
#
#    OUTSTANDING_PRINCIPAL  PAID_PRINCIPAL  PAID_INTEREST  MONTHOPENING  \
# 0           2.262177e+06    9.447930e+06   2.617476e+06  9.338009e+06
# 1           2.157467e+06    9.552641e+06   2.638213e+06  9.233299e+06
# 2           2.051797e+06    9.658311e+06   2.657989e+06  9.127629e+06
# 3           1.944731e+06    9.765377e+06   2.676370e+06  9.020563e+06
# 4           1.836705e+06    9.873402e+06   2.693792e+06  8.912538e+06
#
#   LAST_RECEIPT_DATE  LAST_RECEIPT_AMOUNT  NET_LTV  COMPLETED_TENURE  \
# 0        2013-11-01              83559.0    40.06                39
# 1        2013-12-01              83559.0    40.06                40
# 2        2014-01-01              83559.0    40.06                41
# 3        1974-02-02              83559.0    40.06                41
# 4        2014-03-01              83559.0    40.06                43
#
#    BALANCE_TENURE  DPD  FOIR PRODUCT    SCHEMEID NPA_IN_LAST_MONTH  \
# 0            19.0  0.0   0.6      HL  10901100.0               NaN
# 1            18.0  0.0   0.6      HL  10901100.0               NaN
# 2            17.0  0.0   0.6      HL  10901100.0               NaN
# 3            17.0  0.0   0.6      HL  10901100.0               NaN
# 4            15.0  0.0   0.6      HL  10901100.0               NaN
#
#   NPA_IN_CURRENT_MONTH  MOB
# 0                  NaN   39
# 1                  NaN   40
# 2                  NaN   41
# 3                  NaN   42
# 4                  NaN   43

# %%
### this seems to be time-varient, a single agreements has many datapoints, 
# which shows status of the agreeement at diffrent point of time

# %%
train_data[~train_data['CUSTOMERID'].isin(customers['CUSTOMERID'].unique())]['FORECLOSURE'].value_counts()
# Out:
# 0    175346
# 1      6706
# Name: FORECLOSURE, dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# Build a function fe_to_do for feature engineering derived from EDA

# %% [markdown]
# As we already know that around 2/3rd customer data is missing, so we will perform EDA for agreements first then figure out the customer data.

# %% [markdown]
# scaling down maybe normalize, box-cox,
# will prefer normalize

# %%
agreements.columns
# Out:
# Index(['AGREEMENTID', 'CUSTOMERID', 'LOAN_AMT', 'NET_DISBURSED_AMT',
#        'INTEREST_START_DATE', 'CURRENT_ROI', 'ORIGNAL_ROI', 'CURRENT_TENOR',
#        'ORIGNAL_TENOR', 'DUEDAY', 'AUTHORIZATIONDATE', 'CITY',
#        'PRE_EMI_DUEAMT', 'PRE_EMI_RECEIVED_AMT', 'PRE_EMI_OS_AMOUNT',
#        'EMI_DUEAMT', 'EMI_RECEIVED_AMT', 'EMI_OS_AMOUNT', 'EXCESS_AVAILABLE',
#        'EXCESS_ADJUSTED_AMT', 'BALANCE_EXCESS', 'NET_RECEIVABLE',
#        'OUTSTANDING_PRINCIPAL', 'PAID_PRINCIPAL', 'PAID_INTEREST',
#        'MONTHOPENING', 'LAST_RECEIPT_DATE', 'LAST_RECEIPT_AMOUNT', 'NET_LTV',
#        'COMPLETED_TENURE', 'BALANCE_TENURE', 'DPD', 'FOIR', 'PRODUCT',
#        'SCHEMEID', 'NPA_IN_LAST_MONTH', 'NPA_IN_CURRENT_MONTH', 'MOB'],
#       dtype='object')

# %% [markdown]
# ### Univariate Analysis

# %%
categorical = train_data.select_dtypes(include=[np.object])
categorical = categorical.columns

numeric = train_data.select_dtypes(include=[np.int,np.float])
numeric = numeric.columns

# %%
categorical, numeric
# Out:
# (Index(['CITY', 'PRODUCT', 'NPA_IN_LAST_MONTH', 'NPA_IN_CURRENT_MONTH'], dtype='object'),
#  Index(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID', 'LOAN_AMT',
#         'NET_DISBURSED_AMT', 'CURRENT_ROI', 'ORIGNAL_ROI', 'CURRENT_TENOR',
#         'ORIGNAL_TENOR', 'DUEDAY', 'PRE_EMI_DUEAMT', 'PRE_EMI_RECEIVED_AMT',
#         'PRE_EMI_OS_AMOUNT', 'EMI_DUEAMT', 'EMI_RECEIVED_AMT', 'EMI_OS_AMOUNT',
#         'EXCESS_AVAILABLE', 'EXCESS_ADJUSTED_AMT', 'BALANCE_EXCESS',
#         'NET_RECEIVABLE', 'OUTSTANDING_PRINCIPAL', 'PAID_PRINCIPAL',
#         'PAID_INTEREST', 'MONTHOPENING', 'LAST_RECEIPT_AMOUNT', 'NET_LTV',
#         'COMPLETED_TENURE', 'BALANCE_TENURE', 'DPD', 'FOIR', 'SCHEMEID', 'MOB'],
#        dtype='object'))

# %%
## although 'AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID', 'SCHEMEID' ,comes as a categorical varaible only

# %% [markdown]
# ## Target Analysis

# %%
plt.figure(figsize=(2,2))
#### countplot of the target variable "Foreclosure"
## fill your code here

sns.countplot(train_data['FORECLOSURE'])

# %% [markdown]
# ## Variable Analysis

# %%
# use value_counts() method for variable "NPA_IN_LAST_MONTH"

## fill your code here
train_data['NPA_IN_LAST_MONTH'].value_counts()
# Out:
# 0      7308
# #N/     508
# Yes     214
# NPA       3
# yes       1
# Name: NPA_IN_LAST_MONTH, dtype: int64

# %%
count = 0
plt.figure(figsize=(12,12))i])

for i in categorical.drop(['CITY']):
    count+=1
    plt.subplot(int(str(33)+str(count)))

    ## fill your code here for plotting the countplot
    sns.countplot(train_data[
    plt.title(i)
plt.show()

# %%
train_data['FORECLOSURE'].value_counts()
# Out:
# 0    331719
# 1     42866
# Name: FORECLOSURE, dtype: int64

# %%
# this is an unbalanced dataset
## we can use smote to deal with this

# %%
## plot count plot with hue as FORECLOSURE during bivariate analysis

count = 0
plt.figure(figsize=(12,12))
for i in categorical.drop(['CITY']):
    count+=1
    plt.subplot(int(str(33)+str(count)))

    ## fill your code here for plotting the countplot
    sns.countplot(train_data[i],hue=train_data['FORECLOSURE'])

    plt.title(i)
plt.show()

# %% [markdown]
# ### FE to do
# 1. include this small dummy categories into its parent categories

# %%
numeric
# Out:
# Index(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID', 'LOAN_AMT',
#        'NET_DISBURSED_AMT', 'CURRENT_ROI', 'ORIGNAL_ROI', 'CURRENT_TENOR',
#        'ORIGNAL_TENOR', 'DUEDAY', 'PRE_EMI_DUEAMT', 'PRE_EMI_RECEIVED_AMT',
#        'PRE_EMI_OS_AMOUNT', 'EMI_DUEAMT', 'EMI_RECEIVED_AMT', 'EMI_OS_AMOUNT',
#        'EXCESS_AVAILABLE', 'EXCESS_ADJUSTED_AMT', 'BALANCE_EXCESS',
#        'NET_RECEIVABLE', 'OUTSTANDING_PRINCIPAL', 'PAID_PRINCIPAL',
#        'PAID_INTEREST', 'MONTHOPENING', 'LAST_RECEIPT_AMOUNT', 'NET_LTV',
#        'COMPLETED_TENURE', 'BALANCE_TENURE', 'DPD', 'FOIR', 'SCHEMEID', 'MOB'],
#       dtype='object')

# %%
count = 0
done_list  = []

plt.figure(figsize=(12,12))

for i in numeric.drop(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID']):
    if count<9:
        count+=1
        plt.subplot(int(str(33)+str(count)))
        
        ### fill your code here to plot the kdeplot
        sns.kdeplot(train_data[i])

        plt.title(i)
        
        done_list.append(i)
        
plt.show()

# %% [markdown]
# ## FE to do
# 1. normalize loan_amount, net_distributed,pre_emi_due, pre_emi_recieved, in both train and test using same kind of transformation

# %%
count = 0
plt.figure(figsize=(12,12))
for i in numeric.drop(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID']+done_list):
    if count<9:
        count+=1
        plt.subplot(int(str(33)+str(count)))
        sns.boxplot(train_data[i].dropna())
        plt.title(i)
        done_list.append(i)
plt.show()

# %% [markdown]
# ## FE to do
# 1. scale down all of the above in both train and test using same kind of transformation

# %%
"""

Fill the code for remaining variable


"""
# Out:
# '\n\nFill the code for remaining variable\n\n\n'

# %% [markdown]
# ## FE to do
# 1. scale down PAID_Principal, paid_intereset,monthopening,last_recipt_amount, in both train and test using same kind of transformation

# %% [markdown]
# ## Bivariate Ananlysis

# %%
count = 0
plt.figure(figsize=(12,12))
for i in categorical.drop(['CITY']):
    count+=1
    plt.subplot(int(str(33)+str(count)))
#     plt.subplot()
    sns.countplot(train_data[i],hue = train_data['FORECLOSURE'])
    plt.title(i)
plt.show()

# %%
count = 0
plt.figure(figsize=(4,6))
for i in categorical.drop(['CITY']):
    count+=1
#     plt.subplot(int(str(33)+str(count)))
#     plt.subplot()
    var = pd.crosstab(train_data[i],train_data['FORECLOSURE']) 
    var.div(var.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(3,3))
#     sns.countplot(train_data[i],hue = train_data['FORECLOSURE'])
#     plt.title(i)
#     plt.show()

# %% [markdown]
# ### FE to do
# 1. we notice that LAP and STLAP agreements product never undergo foreclosure, so we can create a common feature named as is_lap_or_stlap
# 2. other thing to notice is that null NAP barely undergo foreclosure, anyways we will one-hot encode the feature so no need to create and extra one( although we will merge its subcategories into a major one, such as YES and yes)

# %%
#numeric vs target

# %%
numeric
# Out:
# Index(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID', 'LOAN_AMT',
#        'NET_DISBURSED_AMT', 'CURRENT_ROI', 'ORIGNAL_ROI', 'CURRENT_TENOR',
#        'ORIGNAL_TENOR', 'DUEDAY', 'PRE_EMI_DUEAMT', 'PRE_EMI_RECEIVED_AMT',
#        'PRE_EMI_OS_AMOUNT', 'EMI_DUEAMT', 'EMI_RECEIVED_AMT', 'EMI_OS_AMOUNT',
#        'EXCESS_AVAILABLE', 'EXCESS_ADJUSTED_AMT', 'BALANCE_EXCESS',
#        'NET_RECEIVABLE', 'OUTSTANDING_PRINCIPAL', 'PAID_PRINCIPAL',
#        'PAID_INTEREST', 'MONTHOPENING', 'LAST_RECEIPT_AMOUNT', 'NET_LTV',
#        'COMPLETED_TENURE', 'BALANCE_TENURE', 'DPD', 'FOIR', 'SCHEMEID', 'MOB'],
#       dtype='object')

# %%
plt.figure(figsize=(2,2))
train_data.groupby('FORECLOSURE')['LOAN_AMT'].mean().plot('bar')

# %% [markdown]
# ##### we notice that foreclosure agreements loan amounts are slightly lower but still its more or less the same lets plot it for all numeric variables

# %%
count = 0
done_list_new = []

plt.figure(figsize=(12,12))

for i in numeric.drop(['AGREEMENTID', 'FORECLOSURE', 'CUSTOMERID']+done_list_new):
    if count<9:
        count+=1
        plt.subplot(int(str(33)+str(count)))

        train_data.groupby('FORECLOSURE')[i].mean().plot('bar')

        # fill the line for groupby plot of all variable

        plt.title(i)
        done_list_new.append(i)
plt.show()

# %% [markdown]
# 1. LOAN_AMT , NET_DISTRIBUTED_AMT mean is lower for foreclosure, lets bin this variables to explore them more, while ROIs are exact same.
# 2. both current and original tenor, and dueday are higher for forclosure which confirms the idleness of borrower, which lead to foreclosure
# 3. both pre_emi_due and recieved amt for non-foreclosure is higher, but lets check their diffrence whichis due-recieved, which will give a clear picture of what is happening

# %%
print(train_data['LOAN_AMT'].describe(), '\n')
print(train_data['NET_DISBURSED_AMT'].describe())
# Out:
# count    3.745850e+05
# mean     5.859862e+06
# std      1.269848e+07
# min      3.753240e+04
# 25%      1.523815e+06
# 50%      2.627268e+06
# 75%      5.254535e+06
# max      4.245665e+08
# Name: LOAN_AMT, dtype: float64
#
# count    3.745850e+05
# mean     5.813433e+06
# std      1.261270e+07
# min      3.753240e+04
# 25%      1.501296e+06
# 50%      2.579226e+06
# 75%      5.229163e+06
# max      4.245665e+08
# Name: NET_DISBURSED_AMT, dtype: float64

# %%
bins=[3.753240e+04,1.523815e+06, 2.627268e+06,5.254535e+06,4.245665e+08] 
group=['Low','Average','High', 'Very high'] 
train_data['LOAN_AMT_BINNED']=pd.cut(train_data['LOAN_AMT'],bins,labels=group)

# %%
var = pd.crosstab(train_data['LOAN_AMT_BINNED'],train_data['FORECLOSURE']) 
var.div(var.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(3,3))

# %% [markdown]
# 1. for low and average loan_amount, foreclosure is slightly more
# 2. and from the stats above it seems that net_amnt would also show a same kind of behaviour if binned

# %%
"""

fill code for groupby plot viz of remaining variables,

hint - excluding the done_list_new variables

"""
# Out:
# '\n\nfill code for groupby plot viz of remaining variables,\n\nhint - excluding the done_list_new variables\n\n'

# %%
"""

#we still have some more variables left, 

fill the code excluding the updated done_list_new

"""
# Out:
# '\n\n#we still have some more variables left, \n\nfill the code excluding the updated done_list_new\n\n'

# %%
## correlation matrix

# %%
corr = train_data.corr()

# %%
corr
# Out:
#                        AGREEMENTID  FORECLOSURE  CUSTOMERID  LOAN_AMT  \
# AGREEMENTID               1.000000    -0.276735    1.000000 -0.057637
# FORECLOSURE              -0.276735     1.000000   -0.276817 -0.004955
# CUSTOMERID                1.000000    -0.276817    1.000000 -0.057262
# LOAN_AMT                 -0.057637    -0.004955   -0.057262  1.000000
# NET_DISBURSED_AMT        -0.060163    -0.004698   -0.059767  0.998161
# CURRENT_ROI              -0.335206    -0.006418   -0.336399 -0.074621
# ORIGNAL_ROI              -0.357149    -0.010118   -0.358496 -0.093021
# CURRENT_TENOR             0.162709     0.104760    0.161864 -0.064283
# ORIGNAL_TENOR             0.132912     0.139815    0.131735 -0.086580
# DUEDAY                   -0.339620     0.158156   -0.339993 -0.001833
# PRE_EMI_DUEAMT           -0.078657    -0.005782   -0.078518  0.454613
# PRE_EMI_RECEIVED_AMT     -0.078902    -0.005667   -0.078764  0.454900
# PRE_EMI_OS_AMOUNT         0.002655    -0.004267    0.002713  0.022632
# EMI_DUEAMT               -0.222072     0.004030   -0.222126  0.622291
# EMI_RECEIVED_AMT         -0.219885     0.005082   -0.219936  0.620182
# EMI_OS_AMOUNT            -0.050581    -0.010219   -0.050611  0.100738
# EXCESS_AVAILABLE         -0.073308     0.004263   -0.073310  0.258626
# EXCESS_ADJUSTED_AMT      -0.076472     0.004619   -0.076488  0.247652
# BALANCE_EXCESS            0.006523    -0.001191    0.006591  0.081043
# NET_RECEIVABLE           -0.046195    -0.007843   -0.046261  0.034008
# OUTSTANDING_PRINCIPAL    -0.033355    -0.005219   -0.032916  0.978608
# PAID_PRINCIPAL           -0.027275    -0.001777   -0.027278  0.178671
# PAID_INTEREST            -0.240037     0.012129   -0.240089  0.645001
# MONTHOPENING             -0.043246    -0.003318   -0.042818  0.988506
# LAST_RECEIPT_AMOUNT      -0.044941    -0.005080   -0.044786  0.430607
# NET_LTV                   0.155955     0.032306    0.154637  0.076696
# COMPLETED_TENURE         -0.595633     0.070595   -0.595532  0.053083
# BALANCE_TENURE            0.327130     0.077161    0.326361 -0.075680
# DPD                      -0.082761    -0.000477   -0.082749  0.020254
# FOIR                     -0.004025    -0.001947   -0.004025  0.013468
# SCHEMEID                  0.517871    -0.244691    0.517878 -0.108109
# MOB                      -0.604813     0.070176   -0.604588  0.050904
#
#                        NET_DISBURSED_AMT  CURRENT_ROI  ORIGNAL_ROI  \
# AGREEMENTID                    -0.060163    -0.335206    -0.357149
# FORECLOSURE                    -0.004698    -0.006418    -0.010118
# CUSTOMERID                     -0.059767    -0.336399    -0.358496
# LOAN_AMT                        0.998161    -0.074621    -0.093021
# NET_DISBURSED_AMT               1.000000    -0.073207    -0.091704
# CURRENT_ROI                    -0.073207     1.000000     0.952998
# ORIGNAL_ROI                    -0.091704     0.952998     1.000000
# CURRENT_TENOR                  -0.064738    -0.346139    -0.407359
# ORIGNAL_TENOR                  -0.087323    -0.419062    -0.417702
# DUEDAY                         -0.000935     0.312626     0.308721
# PRE_EMI_DUEAMT                  0.453174     0.006486     0.006460
# PRE_EMI_RECEIVED_AMT            0.453488     0.006487     0.006512
# PRE_EMI_OS_AMOUNT               0.021610     0.000456    -0.001292
# EMI_DUEAMT                      0.627579     0.050090     0.040865
# EMI_RECEIVED_AMT                0.625449     0.047788     0.039787
# EMI_OS_AMOUNT                   0.101628     0.029858     0.016190
# EXCESS_AVAILABLE                0.259845    -0.007278    -0.000669
# EXCESS_ADJUSTED_AMT             0.248942    -0.006436     0.000635
# BALANCE_EXCESS                  0.080844    -0.004786    -0.006204
# NET_RECEIVABLE                  0.034859     0.027879     0.017336
# OUTSTANDING_PRINCIPAL           0.979859    -0.084236    -0.105007
# PAID_PRINCIPAL                  0.179368     0.001059     0.003147
# PAID_INTEREST                   0.650124     0.047260     0.035494
# MONTHOPENING                    0.989950    -0.083705    -0.103953
# LAST_RECEIPT_AMOUNT             0.432006    -0.006321    -0.014684
# NET_LTV                         0.076248    -0.280338    -0.291495
# COMPLETED_TENURE                0.057022     0.143523     0.158882
# BALANCE_TENURE                 -0.077263    -0.365685    -0.427416
# DPD                             0.020781     0.082598     0.072745
# FOIR                            0.011822    -0.001572    -0.001428
# SCHEMEID                       -0.110056    -0.032499    -0.016725
# MOB                             0.054498     0.150552     0.167154
#
#                        CURRENT_TENOR  ORIGNAL_TENOR    DUEDAY  PRE_EMI_DUEAMT  \
# AGREEMENTID                 0.162709       0.132912 -0.339620       -0.078657
# FORECLOSURE                 0.104760       0.139815  0.158156       -0.005782
# CUSTOMERID                  0.161864       0.131735 -0.339993       -0.078518
# LOAN_AMT                   -0.064283      -0.086580 -0.001833        0.454613
# NET_DISBURSED_AMT          -0.064738      -0.087323 -0.000935        0.453174
# CURRENT_ROI                -0.346139      -0.419062  0.312626        0.006486
# ORIGNAL_ROI                -0.407359      -0.417702  0.308721        0.006460
# CURRENT_TENOR               1.000000       0.885681 -0.099819       -0.040237
# ORIGNAL_TENOR               0.885681       1.000000 -0.111624       -0.038229
# DUEDAY                     -0.099819      -0.111624  1.000000        0.054128
# PRE_EMI_DUEAMT             -0.040237      -0.038229  0.054128        1.000000
# PRE_EMI_RECEIVED_AMT       -0.040467      -0.038500  0.053946        0.999563
# PRE_EMI_OS_AMOUNT           0.004867       0.006446  0.009981        0.085800
# EMI_DUEAMT                 -0.101563      -0.118013  0.093138        0.264490
# EMI_RECEIVED_AMT           -0.103975      -0.119208  0.090540        0.262321
# EMI_OS_AMOUNT               0.011664      -0.002835  0.038359        0.055793
# EXCESS_AVAILABLE           -0.102562      -0.017349 -0.000075        0.287917
# EXCESS_ADJUSTED_AMT        -0.104579      -0.016598 -0.000406        0.288664
# BALANCE_EXCESS             -0.002197      -0.005510  0.001547        0.029281
# NET_RECEIVABLE              0.011161       0.001149  0.031171        0.029568
# OUTSTANDING_PRINCIPAL      -0.028456      -0.066144 -0.012341        0.413962
# PAID_PRINCIPAL             -0.041429      -0.021592  0.006439        0.418760
# PAID_INTEREST              -0.050411      -0.071910  0.094045        0.338813
# MONTHOPENING               -0.042262      -0.067600 -0.010872        0.417340
# LAST_RECEIPT_AMOUNT        -0.069574      -0.067053  0.010859        0.223000
# NET_LTV                     0.272525       0.309503 -0.069390        0.024241
# COMPLETED_TENURE           -0.073062      -0.047754  0.271167        0.028144
# BALANCE_TENURE              0.956074       0.841792 -0.172989       -0.045878
# DPD                        -0.000073      -0.012402  0.116428        0.023876
# FOIR                       -0.013553      -0.014413  0.010393        0.006892
# SCHEMEID                   -0.009202       0.003289 -0.308265       -0.058839
# MOB                        -0.072594      -0.045727  0.282216        0.074521
#
#                        PRE_EMI_RECEIVED_AMT  PRE_EMI_OS_AMOUNT  EMI_DUEAMT  \
# AGREEMENTID                       -0.078902           0.002655   -0.222072
# FORECLOSURE                       -0.005667          -0.004267    0.004030
# CUSTOMERID                        -0.078764           0.002713   -0.222126
# LOAN_AMT                           0.454900           0.022632    0.622291
# NET_DISBURSED_AMT                  0.453488           0.021610    0.627579
# CURRENT_ROI                        0.006487           0.000456    0.050090
# ORIGNAL_ROI                        0.006512          -0.001292    0.040865
# CURRENT_TENOR                     -0.040467           0.004867   -0.101563
# ORIGNAL_TENOR                     -0.038500           0.006446   -0.118013
# DUEDAY                             0.053946           0.009981    0.093138
# PRE_EMI_DUEAMT                     0.999563           0.085800    0.264490
# PRE_EMI_RECEIVED_AMT               1.000000           0.056326    0.265202
# PRE_EMI_OS_AMOUNT                  0.056326           1.000000   -0.005227
# EMI_DUEAMT                         0.265202          -0.005227    1.000000
# EMI_RECEIVED_AMT                   0.263053          -0.006036    0.995330
# EMI_OS_AMOUNT                      0.055686           0.007582    0.174951
# EXCESS_AVAILABLE                   0.288446           0.002629    0.244360
# EXCESS_ADJUSTED_AMT                0.289193           0.002671    0.244468
# BALANCE_EXCESS                     0.029339           0.000102    0.027325
# NET_RECEIVABLE                     0.029023           0.020495    0.128858
# OUTSTANDING_PRINCIPAL              0.414128           0.023826    0.524969
# PAID_PRINCIPAL                     0.419652          -0.000324    0.117974
# PAID_INTEREST                      0.339581          -0.001797    0.965930
# MONTHOPENING                       0.417532           0.023213    0.549933
# LAST_RECEIPT_AMOUNT                0.223304           0.005857    0.325159
# NET_LTV                            0.024079           0.007186    0.041777
# COMPLETED_TENURE                   0.028667          -0.015646    0.354035
# BALANCE_TENURE                    -0.046246           0.009147   -0.198976
# DPD                                0.021308           0.088280    0.078565
# FOIR                               0.006910          -0.000114    0.001013
# SCHEMEID                          -0.058905          -0.001973   -0.154367
# MOB                                0.074714          -0.001223    0.350487
#
#                        EMI_RECEIVED_AMT  EMI_OS_AMOUNT  EXCESS_AVAILABLE  \
# AGREEMENTID                   -0.219885      -0.050581         -0.073308
# FORECLOSURE                    0.005082      -0.010219          0.004263
# CUSTOMERID                    -0.219936      -0.050611         -0.073310
# LOAN_AMT                       0.620182       0.100738          0.258626
# NET_DISBURSED_AMT              0.625449       0.101628          0.259845
# CURRENT_ROI                    0.047788       0.029858         -0.007278
# ORIGNAL_ROI                    0.039787       0.016190         -0.000669
# CURRENT_TENOR                 -0.103975       0.011664         -0.102562
# ORIGNAL_TENOR                 -0.119208      -0.002835         -0.017349
# DUEDAY                         0.090540       0.038359         -0.000075
# PRE_EMI_DUEAMT                 0.262321       0.055793          0.287917
# PRE_EMI_RECEIVED_AMT           0.263053       0.055686          0.288446
# PRE_EMI_OS_AMOUNT             -0.006036       0.007582          0.002629
# EMI_DUEAMT                     0.995330       0.174951          0.244360
# EMI_RECEIVED_AMT               1.000000       0.079089          0.243127
# EMI_OS_AMOUNT                  0.079089       1.000000          0.043695
# EXCESS_AVAILABLE               0.243127       0.043695          1.000000
# EXCESS_ADJUSTED_AMT            0.244772       0.028023          0.978193
# BALANCE_EXCESS                 0.019955       0.078648          0.216400
# NET_RECEIVABLE                 0.053479       0.785223         -0.097899
# OUTSTANDING_PRINCIPAL          0.521568       0.101521          0.110686
# PAID_PRINCIPAL                 0.118850       0.006086          0.542022
# PAID_INTEREST                  0.968411       0.097675          0.249525
# MONTHOPENING                   0.546594       0.104080          0.207116
# LAST_RECEIPT_AMOUNT            0.320471       0.090056          0.349749
# NET_LTV                        0.039455       0.029000          0.018830
# COMPLETED_TENURE               0.348809       0.098376          0.112717
# BALANCE_TENURE                -0.199693      -0.018012         -0.128983
# DPD                            0.020767       0.599506          0.022248
# FOIR                           0.001057      -0.000313         -0.000409
# SCHEMEID                      -0.153222      -0.031329         -0.054947
# MOB                            0.345182       0.098725          0.114366
#
#                        EXCESS_ADJUSTED_AMT  BALANCE_EXCESS  NET_RECEIVABLE  \
# AGREEMENTID                      -0.076472        0.006523       -0.046195
# FORECLOSURE                       0.004619       -0.001191       -0.007843
# CUSTOMERID                       -0.076488        0.006591       -0.046261
# LOAN_AMT                          0.247652        0.081043        0.034008
# NET_DISBURSED_AMT                 0.248942        0.080844        0.034859
# CURRENT_ROI                      -0.006436       -0.004786        0.027879
# ORIGNAL_ROI                       0.000635       -0.006204        0.017336
# CURRENT_TENOR                    -0.104579       -0.002197        0.011161
# ORIGNAL_TENOR                    -0.016598       -0.005510        0.001149
# DUEDAY                           -0.000406        0.001547        0.031171
# PRE_EMI_DUEAMT                    0.288664        0.029281        0.029568
# PRE_EMI_RECEIVED_AMT              0.289193        0.029339        0.029023
# PRE_EMI_OS_AMOUNT                 0.002671        0.000102        0.020495
# EMI_DUEAMT                        0.244468        0.027325        0.128858
# EMI_RECEIVED_AMT                  0.244772        0.019955        0.053479
# EMI_OS_AMOUNT                     0.028023        0.078648        0.785223
# EXCESS_AVAILABLE                  0.978193        0.216400       -0.097899
# EXCESS_ADJUSTED_AMT               1.000000        0.008904        0.017879
# BALANCE_EXCESS                    0.008904        1.000000       -0.555376
# NET_RECEIVABLE                    0.017879       -0.555376        1.000000
# OUTSTANDING_PRINCIPAL             0.095598        0.083531        0.033133
# PAID_PRINCIPAL                    0.554672        0.002274        0.003659
# PAID_INTEREST                     0.250805        0.022405        0.067518
# MONTHOPENING                      0.194146        0.084559        0.034620
# LAST_RECEIPT_AMOUNT               0.266077        0.447740       -0.188954
# NET_LTV                           0.018690        0.002801        0.022548
# COMPLETED_TENURE                  0.114702        0.003503        0.079642
# BALANCE_TENURE                   -0.131452       -0.003083       -0.012977
# DPD                               0.014909        0.037032        0.478221
# FOIR                             -0.000395       -0.000114       -0.000192
# SCHEMEID                         -0.056820        0.002545       -0.027736
# MOB                               0.116295        0.003956        0.079858
#
#                        OUTSTANDING_PRINCIPAL  PAID_PRINCIPAL  PAID_INTEREST  \
# AGREEMENTID                        -0.033355       -0.027275      -0.240037
# FORECLOSURE                        -0.005219       -0.001777       0.012129
# CUSTOMERID                         -0.032916       -0.027278      -0.240089
# LOAN_AMT                            0.978608        0.178671       0.645001
# NET_DISBURSED_AMT                   0.979859        0.179368       0.650124
# CURRENT_ROI                        -0.084236        0.001059       0.047260
# ORIGNAL_ROI                        -0.105007        0.003147       0.035494
# CURRENT_TENOR                      -0.028456       -0.041429      -0.050411
# ORIGNAL_TENOR                      -0.066144       -0.021592      -0.071910
# DUEDAY                             -0.012341        0.006439       0.094045
# PRE_EMI_DUEAMT                      0.413962        0.418760       0.338813
# PRE_EMI_RECEIVED_AMT                0.414128        0.419652       0.339581
# PRE_EMI_OS_AMOUNT                   0.023826       -0.000324      -0.001797
# EMI_DUEAMT                          0.524969        0.117974       0.965930
# EMI_RECEIVED_AMT                    0.521568        0.118850       0.968411
# EMI_OS_AMOUNT                       0.101521        0.006086       0.097675
# EXCESS_AVAILABLE                    0.110686        0.542022       0.249525
# EXCESS_ADJUSTED_AMT                 0.095598        0.554672       0.250805
# BALANCE_EXCESS                      0.083531        0.002274       0.022405
# NET_RECEIVABLE                      0.033133        0.003659       0.067518
# OUTSTANDING_PRINCIPAL               1.000000        0.079861       0.566798
# PAID_PRINCIPAL                      0.079861        1.000000       0.133828
# PAID_INTEREST                       0.566798        0.133828       1.000000
# MONTHOPENING                        0.992719        0.093124       0.588334
# LAST_RECEIPT_AMOUNT                 0.393853        0.149651       0.320383
# NET_LTV                             0.078931        0.004676       0.051183
# COMPLETED_TENURE                    0.011305        0.033181       0.369020
# BALANCE_TENURE                     -0.029917       -0.048471      -0.155573
# DPD                                 0.020292        0.000940       0.030149
# FOIR                                0.012541        0.000225       0.000571
# SCHEMEID                           -0.097382       -0.022423      -0.168947
# MOB                                 0.008582        0.037176       0.368903
#
#                        MONTHOPENING  LAST_RECEIPT_AMOUNT   NET_LTV  \
# AGREEMENTID               -0.043246            -0.044941  0.155955
# FORECLOSURE               -0.003318            -0.005080  0.032306
# CUSTOMERID                -0.042818            -0.044786  0.154637
# LOAN_AMT                   0.988506             0.430607  0.076696
# NET_DISBURSED_AMT          0.989950             0.432006  0.076248
# CURRENT_ROI               -0.083705            -0.006321 -0.280338
# ORIGNAL_ROI               -0.103953            -0.014684 -0.291495
# CURRENT_TENOR             -0.042262            -0.069574  0.272525
# ORIGNAL_TENOR             -0.067600            -0.067053  0.309503
# DUEDAY                    -0.010872             0.010859 -0.069390
# PRE_EMI_DUEAMT             0.417340             0.223000  0.024241
# PRE_EMI_RECEIVED_AMT       0.417532             0.223304  0.024079
# PRE_EMI_OS_AMOUNT          0.023213             0.005857  0.007186
# EMI_DUEAMT                 0.549933             0.325159  0.041777
# EMI_RECEIVED_AMT           0.546594             0.320471  0.039455
# EMI_OS_AMOUNT              0.104080             0.090056  0.029000
# EXCESS_AVAILABLE           0.207116             0.349749  0.018830
# EXCESS_ADJUSTED_AMT        0.194146             0.266077  0.018690
# BALANCE_EXCESS             0.084559             0.447740  0.002801
# NET_RECEIVABLE             0.034620            -0.188954  0.022548
# OUTSTANDING_PRINCIPAL      0.992719             0.393853  0.078931
# PAID_PRINCIPAL             0.093124             0.149651  0.004676
# PAID_INTEREST              0.588334             0.320383  0.051183
# MONTHOPENING               1.000000             0.412795  0.079630
# LAST_RECEIPT_AMOUNT        0.412795             1.000000  0.025619
# NET_LTV                    0.079630             0.025619  1.000000
# COMPLETED_TENURE           0.027727             0.044849 -0.061853
# BALANCE_TENURE            -0.047647            -0.078239  0.272882
# DPD                        0.022115             0.044173  0.045356
# FOIR                       0.012292             0.006789 -0.005027
# SCHEMEID                  -0.103386            -0.049243  0.108982
# MOB                        0.024719             0.044666 -0.063900
#
#                        COMPLETED_TENURE  BALANCE_TENURE       DPD      FOIR  \
# AGREEMENTID                   -0.595633        0.327130 -0.082761 -0.004025
# FORECLOSURE                    0.070595        0.077161 -0.000477 -0.001947
# CUSTOMERID                    -0.595532        0.326361 -0.082749 -0.004025
# LOAN_AMT                       0.053083       -0.075680  0.020254  0.013468
# NET_DISBURSED_AMT              0.057022       -0.077263  0.020781  0.011822
# CURRENT_ROI                    0.143523       -0.365685  0.082598 -0.001572
# ORIGNAL_ROI                    0.158882       -0.427416  0.072745 -0.001428
# CURRENT_TENOR                 -0.073062        0.956074 -0.000073 -0.013553
# ORIGNAL_TENOR                 -0.047754        0.841792 -0.012402 -0.014413
# DUEDAY                         0.271167       -0.172989  0.116428  0.010393
# PRE_EMI_DUEAMT                 0.028144       -0.045878  0.023876  0.006892
# PRE_EMI_RECEIVED_AMT           0.028667       -0.046246  0.021308  0.006910
# PRE_EMI_OS_AMOUNT             -0.015646        0.009147  0.088280 -0.000114
# EMI_DUEAMT                     0.354035       -0.198976  0.078565  0.001013
# EMI_RECEIVED_AMT               0.348809       -0.199693  0.020767  0.001057
# EMI_OS_AMOUNT                  0.098376       -0.018012  0.599506 -0.000313
# EXCESS_AVAILABLE               0.112717       -0.128983  0.022248 -0.000409
# EXCESS_ADJUSTED_AMT            0.114702       -0.131452  0.014909 -0.000395
# BALANCE_EXCESS                 0.003503       -0.003083  0.037032 -0.000114
# NET_RECEIVABLE                 0.079642       -0.012977  0.478221 -0.000192
# OUTSTANDING_PRINCIPAL          0.011305       -0.029917  0.020292  0.012541
# PAID_PRINCIPAL                 0.033181       -0.048471  0.000940  0.000225
# PAID_INTEREST                  0.369020       -0.155573  0.030149  0.000571
# MONTHOPENING                   0.027727       -0.047647  0.022115  0.012292
# LAST_RECEIPT_AMOUNT            0.044849       -0.078239  0.044173  0.006789
# NET_LTV                       -0.061853        0.272882  0.045356 -0.005027
# COMPLETED_TENURE               1.000000       -0.362195  0.152253 -0.004412
# BALANCE_TENURE                -0.362195        1.000000 -0.044817 -0.011370
# DPD                            0.152253       -0.044817  1.000000 -0.000658
# FOIR                          -0.004412       -0.011370 -0.000658  1.000000
# SCHEMEID                      -0.386036        0.104878 -0.055123 -0.000512
# MOB                            0.990745       -0.359038  0.157124 -0.004070
#
#                        SCHEMEID       MOB
# AGREEMENTID            0.517871 -0.604813
# FORECLOSURE           -0.244691  0.070176
# CUSTOMERID             0.517878 -0.604588
# LOAN_AMT              -0.108109  0.050904
# NET_DISBURSED_AMT     -0.110056  0.054498
# CURRENT_ROI           -0.032499  0.150552
# ORIGNAL_ROI           -0.016725  0.167154
# CURRENT_TENOR         -0.009202 -0.072594
# ORIGNAL_TENOR          0.003289 -0.045727
# DUEDAY                -0.308265  0.282216
# PRE_EMI_DUEAMT        -0.058839  0.074521
# PRE_EMI_RECEIVED_AMT  -0.058905  0.074714
# PRE_EMI_OS_AMOUNT     -0.001973 -0.001223
# EMI_DUEAMT            -0.154367  0.350487
# EMI_RECEIVED_AMT      -0.153222  0.345182
# EMI_OS_AMOUNT         -0.031329  0.098725
# EXCESS_AVAILABLE      -0.054947  0.114366
# EXCESS_ADJUSTED_AMT   -0.056820  0.116295
# BALANCE_EXCESS         0.002545  0.003956
# NET_RECEIVABLE        -0.027736  0.079858
# OUTSTANDING_PRINCIPAL -0.097382  0.008582
# PAID_PRINCIPAL        -0.022423  0.037176
# PAID_INTEREST         -0.168947  0.368903
# MONTHOPENING          -0.103386  0.024719
# LAST_RECEIPT_AMOUNT   -0.049243  0.044666
# NET_LTV                0.108982 -0.063900
# COMPLETED_TENURE      -0.386036  0.990745
# BALANCE_TENURE         0.104878 -0.359038
# DPD                   -0.055123  0.157124
# FOIR                  -0.000512 -0.004070
# SCHEMEID               1.000000 -0.380581
# MOB                   -0.380581  1.000000

# %%
train_data.columns  = train_data.columns.str.lower()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(corr,square=True,cmap='BuPu')

# %%
train_data.drop(['customerid','last_receipt_date','last_receipt_amount','schemeid','npa_in_last_month','npa_in_current_month'],axis=1,inplace=True)

# %%
train_data.columns
# Out:
# Index(['agreementid', 'foreclosure', 'loan_amt', 'net_disbursed_amt',
#        'interest_start_date', 'current_roi', 'orignal_roi', 'current_tenor',
#        'orignal_tenor', 'dueday', 'authorizationdate', 'city',
#        'pre_emi_dueamt', 'pre_emi_received_amt', 'pre_emi_os_amount',
#        'emi_dueamt', 'emi_received_amt', 'emi_os_amount', 'excess_available',
#        'excess_adjusted_amt', 'balance_excess', 'net_receivable',
#        'outstanding_principal', 'paid_principal', 'paid_interest',
#        'monthopening', 'net_ltv', 'completed_tenure', 'balance_tenure', 'dpd',
#        'foir', 'product', 'mob', 'loan_amt_binned'],
#       dtype='object')

# %%
train_data.drop(['interest_start_date', 'authorizationdate', 'city', 'product', 'loan_amt_binned'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_t, x_v, y_t,y_v = train_test_split(train_data.drop(['agreementid','foreclosure'],axis=1),train_data['foreclosure'],test_size=0.2,random_state=56)

# %%
import xgboost

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier()

model.fit(x_t,y_t)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
preds = model.predict(x_v)

# %%
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
np.mean(preds==y_v)
# Out:
# 0.8990616282018767
